# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame , read_csv

# %%
fac = pd.read_csv("Facilities Data.csv")

# %%
neigh_count = fac['neighborhood'].value_counts()

print(neigh_count)
# Out:
# Highland Park                30
# Squirrel Hill South          29
# Perry North                  20
# Brookline                    19
# Strip District               15
# Brighton Heights             14
# Hazelwood                    14
# Carrick                      12
# Elliott                      11
# Lincoln-Lemington-Belmar     11
# South Side Slopes            11
# Morningside                  10
# Point Breeze                  8
# Central Business District     7
# Lower Lawrenceville           7
# Mount Washington              7
# Sheraden                      7
# Shadyside                     7
# Beltzhoover                   7
# Beechview                     6
# Bedford Dwellings             6
# Homewood West                 6
# Bloomfield                    6
# Spring Hill-City View         6
# Lincoln Place                 5
# South Side Flats              5
# Banksville                    5
# Polish Hill                   4
# Garfield                      4
# Westwood                      4
#                              ..
# Manchester                    3
# Oakwood                       3
# Homewood South                3
# North Oakland                 3
# Perry South                   2
# Upper Hill                    2
# Overbrook                     2
# South Oakland                 2
# Duquesne Heights              2
# East Hills                    2
# West End                      2
# Hays                          2
# Chateau                       2
# Swisshelm Park                1
# Point Breeze North            1
# Stanton Heights               1
# Larimer                       1
# Glen Hazel                    1
# Middle Hill                   1
# East Allegheny                1
# Fineview                      1
# Central Northside             1
# Homewood North                1
# Fairywood                     1
# Bon Air                       1
# California-Kirkbride          1
# Central Oakland               1
# Crafton Heights               1
# West Oakland                  1
# Upper Lawrenceville           1
# Name: neighborhood, Length: 75, dtype: int64

# %%
arrests = pd.read_csv("arrests.csv")

# %%
crime_count = arrests['INCIDENTNEIGHBORHOOD'].value_counts()
print(crime_count)
# Out:
# Central Business District      2168
# South Side Flats               1966
# Carrick                        1346
# East Allegheny                 1260
# Homewood South                 1162
# Homewood North                 1049
# East Liberty                   1006
# Marshall-Shadeland              864
# Mount Washington                850
# Bluff                           800
# Knoxville                       769
# Hazelwood                       713
# Brookline                       703
# Lincoln-Lemington-Belmar        702
# Beechview                       701
# Allegheny Center                672
# Sheraden                        665
# Perry South                     645
# Brighton Heights                620
# East Hills                      586
# Middle Hill                     576
# Bloomfield                      564
# Allentown                       550
# Shadyside                       549
# Fineview                        502
# Central North Side              493
# North Shore                     477
# Crawford-Roberts                473
# South Side Slopes               464
# Larimer                         458
#                                ...
# Upper Lawrenceville             115
# Morningside                     111
# Friendship                      111
# Esplen                          107
# Duquesne Heights                103
# Lincoln Place                   102
# Arlington Heights               101
# Polish Hill                      98
# Mount Oliver                     90
# Golden Triangle/Civic Arena      83
# Allegheny West                   76
# Glen Hazel                       70
# Fairywood                        63
# Hays                             62
# Windgap                          60
# Summer Hill                      46
# Oakwood                          45
# Outside State                    39
# Outside County                   36
# St. Clair                        31
# East Carnegie                    29
# Chartiers City                   23
# Central Northside                23
# New Homestead                    23
# Swisshelm Park                   20
# Regent Square                    19
# Ridgemont                        14
# Mt. Oliver Boro                  12
# Troy Hill-Herrs Island            6
# Mt. Oliver Neighborhood           2
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %%
firearms = pd.read_csv("firearms.csv")

# %%
property_values = pd.read_csv("propertyValue.csv")
i = 1
i = int(i)
x = .1
x = int(x)
while i < 27:
    i = str(i)
    property_values[i] = property_values[i]*x
    i = int(i)
    i = i + 1
    x = x + .1
    
property_values['EstimateTotal']=property_values.iloc[:,3:30].sum(axis=1)
property_total = property_values.iloc[:,1:3]
print(property_total)
# Out:
#                  Neighborhood  EstimateTotal
# 0            Allegheny Center          109.1
# 1              Allegheny West          118.2
# 2                   Allentown          300.4
# 3                   Arlington          330.6
# 4           Arlington Heights            0.0
# 5                  Banksville         1303.9
# 6           Bedford Dwellings           27.7
# 7                   Beechview         2182.3
# 8                 Beltzhoover          368.9
# 9                  Bloomfield         2237.1
# 10                      Bluff           62.6
# 11                    Bon Air          335.1
# 12           Brighton Heights         2629.0
# 13                  Brookline         4763.8
# 14       California-Kirkbride          108.0
# 15                    Carrick         2463.4
# 16  Central Business District          655.1
# 17      Central Lawrenceville         1327.0
# 18          Central Northside          825.2
# 19            Central Oakland          263.6
# 20             Chartiers City          178.1
# 21                    Chateau            6.3
# 22            Crafton Heights         1072.4
# 23           Crawford-Roberts          266.3
# 24           Duquesne Heights         1047.1
# 25             East Allegheny          513.0
# 26              East Carnegie          144.1
# 27                 East Hills          465.2
# 28               East Liberty          508.6
# 29                    Elliott          405.4
# ..                        ...            ...
# 61                Perry North         1195.9
# 62                Perry South          679.0
# 63               Point Breeze         2878.0
# 64         Point Breeze North          529.6
# 65                Polish Hill          355.6
# 66              Regent Square          600.1
# 67                  Ridgemont          164.1
# 68                  Shadyside         3432.3
# 69                   Sheraden         1136.2
# 70              South Oakland          442.4
# 71                South Shore            0.0
# 72           South Side Flats         2128.4
# 73          South Side Slopes         1094.7
# 74              Spring Garden          203.4
# 75      Spring Hill-City View          579.1
# 76        Squirrel Hill North         3771.9
# 77        Squirrel Hill South         5448.8
# 78                  St. Clair           30.9
# 79            Stanton Heights         2073.5
# 80             Strip District          118.0
# 81                Summer Hill          465.4
# 82             Swisshelm Park          694.5
# 83            Terrace Village           54.9
# 84                  Troy Hill          586.2
# 85                 Upper Hill          553.7
# 86        Upper Lawrenceville          586.7
# 87                   West End           32.4
# 88               West Oakland          195.3
# 89                   Westwood         1174.2
# 90                    Windgap          505.9
#
# [91 rows x 2 columns]
